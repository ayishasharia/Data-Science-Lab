# %%
import numpy as np
from matplotlib import pyplot as plt
x=np.random.normal(100,2,250)
plt.hist(x)
plt.show()

# %%
from matplotlib import pyplot
pyplot.pie([1,2,3],labels=['a','b','c'])
pyplot.show()

# %%
plt.grid()
x=[1,4,7,10]
y=[2,5,8,11]
plt.plot(x,y)
plt.show()

# %%
from matplotlib import pyplot
x=[1,4,7,10]
y=[2,5,8,11]
plt.plot(x,y,linewidth=1.8,linestyle="dashed")
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
x=np.array([2,4,6,8])
y=np.array([2,4,6,8])
plt.bar(x,y,width=1.2)
plt.show()

# %%
plt.barh(x,y,height=1.2)
plt.show()

# %%
x=[1,4,7,10]
y=[2,5,8,11]
plt.subplot(5,5,1)
plt.plot(x,y)
plt.show()
x=[1,4,7,20]
y=[2,5,8,11]
plt.subplot(5,5,1)
plt.plot(x,y)
plt.show()
